# %%
try:
    from analyzer import analyze_comment
    print("✅ Успех! Файл analyzer.py работает как модуль Python.")

    print("\nПровожу тестовый анализ...")
    test_comment = "Это простой тест."
    analysis_result = analyze_comment(test_comment)

    print("\n--- Результат тестового анализа ---")
    print(analysis_result)
    print("\n🎉 Всё отлично! Модуль готов к передаче бэкенд-разработчику.")

except ImportError:
    print("❌ Ошибка импорта. Убедитесь, что файл называется analyzer.py и лежит в той же папке, что и ваш ноутбук.")
except Exception as e:
    print(f"❌ Произошла ошибка при выполнении анализа: {e}")
# Out:
# Загрузка моделей... Это может занять несколько минут.
# Все рабочие модели успешно загружены!
#
# ✅ Аналитический модуль готов к работе!
# ✅ Успех! Файл analyzer.py работает как модуль Python.
#
# Провожу тестовый анализ...
#
# --- Результат тестового анализа ---
# {'text': 'Это простой тест.', 'language': 'ru', 'moderation_verdict': 'ok', 'sentiment': 'neutral', 'comment_type': 'question'}
#
# 🎉 Всё отлично! Модуль готов к передаче бэкенд-разработчику.
